# %%
#Question 1. List the olympics DataFrame
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
oo=pd.read_csv(r"C:\Users\admin\Desktop\Santosh_Learning\Projects in GIThub\Pandas_SummerOlympics_dataanalysis/olympics.csv", skiprows=4)
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
#Question 2. List only the NOC column using both the ['..'] and dot notation. What type is this object.
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(oo['NOC'])
# Out:
# pandas.core.series.Series

# %%
#Question 3. List the Edition, City, Athlete Name and Medal Columns. What type is this object?
oo[['Edition','City','Athlete','Medal']]
# Out:
#        Edition     City               Athlete   Medal
# 0         1896   Athens         HAJOS, Alfred    Gold
# 1         1896   Athens      HERSCHMANN, Otto  Silver
# 2         1896   Athens     DRIVAS, Dimitrios  Bronze
# 3         1896   Athens    MALOKINIS, Ioannis    Gold
# 4         1896   Athens    CHASAPIS, Spiridon  Silver
# ...        ...      ...                   ...     ...
# 29211     2008  Beijing        ENGLICH, Mirko  Silver
# 29212     2008  Beijing  MIZGAITIS, Mindaugas  Bronze
# 29213     2008  Beijing       PATRIKEEV, Yuri  Bronze
# 29214     2008  Beijing         LOPEZ, Mijain    Gold
# 29215     2008  Beijing        BAROEV, Khasan  Silver
#
# [29216 rows x 4 columns]

# %%
type(oo[['Edition','City','Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Question 4. In which events did Jesse Owens win a Medal?
jo = oo[oo.Athlete == 'OWENS, Jesse']
jo
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
#Question 5. Which country has won the most men's gold medals in singles badminton over the years?
            # sort the results alphabetically by the player's names.
gbm = oo[(oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Sport == 'Badminton')]
gbm.sort_values('Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
#Question 6. Which three countries have won the most medals in recent years (from 1984 to 2008)?
rec = oo[(oo.Edition >= 1984)]
rec.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
#Question 7. Display the male gold medal winners for the 100m track and field sprint event over the years?. List the results
#starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.
mgw = oo[(oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Event == '100m')]
mgw.sort_values('Edition',ascending=False)[['City', 'Edition', 'Athlete', 'NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
"""
Question 8. Plot the number of medals achieved by the Chinese team (men & women) in Beijing 2008 using
> Matplotlib
> Seaborn
"""
mw = oo[(oo.NOC == 'CHN') & (oo.Edition == 2008)]
mw.Gender.value_counts().plot(kind='bar');

# %%
sns.countplot(x='Gender',data=oo);

# %%
#Question 9. How can you use colormaps to give the data more meaning?
sns.countplot(x='Gender',data=oo,palette='bwr')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#Question 10. Plot the number of gold, silver and bronze medals for each gender?
sns.countplot(x='Medal',data=mw,hue='Gender');

# %%
#Question 11. How can you give the data more meaning? Is there anything else you can change to make it more intutive?
sns.countplot(x='Medal',data=mw,hue='Gender',palette='bwr', order=['Gold', 'Silver', 'Bronze']);

# %%
#Q12. Plot the total number of medals awarded at each of the Olympic games throughout history.
oo.Edition.value_counts().plot();

# %%
type(oo.Edition.value_counts()) #.plot();
# Out:
# pandas.core.series.Series

# %%
oo.Edition.value_counts().sort_index() #plot();
# Out:
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().sort_index().plot();

# %%
#Q13. Which countries did not win a medal in the 2008 Olympics? How many countires were there?
lo = oo[oo.Edition == 2008]
lo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
noc=pd.read_csv(r"C:\Users\admin\Desktop\Santosh_Learning\Projects in GIThub\Pandas_SummerOlympics_dataanalysis/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv")
noc
# Out:
#              Country Int Olympic Committee code ISO code        Country.1
# 0        Afghanistan                        AFG       AF      Afghanistan
# 1            Albania                        ALB       AL          Albania
# 2            Algeria                        ALG       DZ          Algeria
# 3    American Samoa*                        ASA       AS  American Samoa*
# 4            Andorra                        AND       AD          Andorra
# ..               ...                        ...      ...              ...
# 196          Vietnam                        VIE       VN          Vietnam
# 197  Virgin Islands*                        ISV       VI  Virgin Islands*
# 198            Yemen                        YEM       YE            Yemen
# 199           Zambia                        ZAM       ZM           Zambia
# 200         Zimbabwe                        ZIM       ZW         Zimbabwe
#
# [201 rows x 4 columns]

# %%
noc.set_index('Int Olympic Committee code',inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008 = lo.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# RSA      1
# MRI      1
# VEN      1
# CHI      1
# MDA      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008'] = medal_2008
noc
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
# ...                                     ...      ...              ...
# VIE                                 Vietnam       VN          Vietnam
# ISV                         Virgin Islands*       VI  Virgin Islands*
# YEM                                   Yemen       YE            Yemen
# ZAM                                  Zambia       ZM           Zambia
# ZIM                                Zimbabwe       ZW         Zimbabwe
#
#                             medal_2008
# Int Olympic Committee code
# ...

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...

# %%
#Q14. Using groupby(), plot the total number of medals awarded at each of the olympic games throughout history.
oo.groupby('Edition').size().plot();

# %%
#Q15. Create a list showing the total number of medals won for each country over the history of the Olympics. For each
#     country, include the year first and most recent Olympic medal wins.
oo.groupby('NOC').agg({'Edition':['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
#Q16. Plot the number of gold medals won by the US male & female athletes throughout the history of the Olympics?
gog = oo[(oo.Medal == 'Gold') & (oo.NOC == 'USA')].groupby(['Edition', 'Gender']).size() #.plot(kind='bar');
gog
# Out:
# Edition  Gender
# 1896     Men        11
# 1900     Men        26
#          Women       1
# 1904     Men       140
#          Women       6
# 1908     Men        34
# 1912     Men        45
# 1920     Men       103
#          Women       7
# 1924     Men        95
#          Women      15
# 1928     Men        34
#          Women       9
# 1932     Men        61
#          Women      17
# 1936     Men        44
#          Women       7
# 1948     Men        75
#          Women       8
# 1952     Men        72
#          Women       7
# 1956     Men        57
#          Women       4
# 1960     Men        51
#          Women      17
# 1964     Men        63
#          Women      15
# 1968     Men        59
#          Women      24
# 1972     Men        37
#          Women      16
# 1976     Men        56
#          Women       7
# 1984     Men       106
#          Women      62
# 1988     Men        49
#          Women      28
# 1992     Men        57
#          Women      32
# ...

# %%
gog.unstack('Gender',fill_value=0).plot();

# %%
#Q17. Plot the five athletes who have won the most gold medals over the history of the Olympics. When there is a tie, 
#     consider the number of silver medals, and then bronze medals.
g = oo.groupby(['Athlete', 'Medal']).size().unstack('Medal',fill_value=0)
h = g.sort_values(['Gold', 'Silver', 'Bronze'],ascending=False)
i = h[['Gold','Silver','Bronze']]
i.head().plot(kind='bar');

# %%
#Q18: From Q17, change the color of gold, Silver and Bronze to provide more intutive meaning to the graph.
from matplotlib.colors import ListedColormap
gsb=['#dbb40c', '#c5c9c7', '#a87900']
my_gsb = ListedColormap(sns.color_palette(gsb))

# %%
i.head().plot(kind='bar', colormap=my_gsb);

# %%
#Q19: In every Olympics, which US athlete has won the most total number of medals? Include the athlete's discipline.
gy = oo[oo.NOC == 'USA'] #.groupby(['Athlete','Medals']).size()
gy_med = gy.groupby(['Edition','Athlete','Medal']).size().unstack('Medal',fill_value=0)
gy_med['Total'] = gy_med['Gold'] + gy_med['Bronze'] + gy_med['Silver']
gy_med.reset_index(inplace=True)
tu = [group.sort_values('Total',ascending=False)[:1] for year, group in gy_med.groupby('Edition')]
tu
top = pd.DataFrame()
for i in tu:
    top = top.append(i)
top
# Out:
# Medal  Edition                      Athlete  Bronze  Gold  Silver  Total
# 5         1896              GARRETT, Robert       0     2       2      4
# 14        1900               BAXTER, Irving       0     2       3      5
# 153       1904                 HEIDA, Anton       0     5       1      6
# 363       1908             SHERIDAN, Martin       1     2       0      3
# 421       1912        OSBURN, Carl Townsend       1     1       2      4
# 506       1920                  LEE, Willis       1     5       1      7
# 733       1924          WEISSMULLER, Johnny       1     3       0      4
# 800       1928       OSIPOWICH, Albina Lucy       0     2       0      2
# 859       1932           DIDRIKSON, Mildred       0     2       1      3
# 1028      1936                 OWENS, Jesse       0     4       0      4
# 1128      1948      MCLANE, James Price Jr.       0     2       1      3
# 1234      1952          KONNO, Ford Hiroshi       0     2       1      3
# ...
