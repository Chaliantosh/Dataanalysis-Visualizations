# %%
import pandas as pd
import numpy as np

# %%
"""
There are two datasets provided by boston PD from june 15 2015 Aug 17 2019:
1. crime_boston.csv: Contains info about crime incident reports.
2. offense_codes_boston.xlsx: Contains description of offense codes.
"""
# Out:
# '\nThere are two datasets provided by boston PD from june 15 2015 Aug 17 2019:\n1. crime_boston.csv: Contains info about crime incident reports.\n2. offense_codes_boston.xlsx: Contains description of offense codes.\n'

# %%
#Dataset-A containing crime incident reports
crime=pd.read_csv(r'C:\Users\admin\Desktop\crime_boston.csv')

#Dataset-B containing offense codes
offense=pd.read_excel(r'C:\Users\admin\Desktop\offense_codes_boston.xlsx')

# %% [markdown]
# # Granularity

# %%
crime=pd.read_csv(r'C:\Users\admin\Desktop\crime_boston.csv')
crime
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0           I192064813          3006               Medical Assistance
# 1           I192064810          3410                            Towed
# 2           I192064808          2003  Offenses Against Child / Family
# 3           I192064803           802                   Simple Assault
# 4           I192064800          3114             Investigate Property
# ...                ...           ...                              ...
# 413667   I020691165-00          3125                  Warrant Arrests
# 413668   I020674147-00          3125                  Warrant Arrests
# 413669   I020669075-00          3125                  Warrant Arrests
# 413670   I020662996-00          3125                  Warrant Arrests
# 413671   I010370257-00          3125                  Warrant Arrests
#
#                     OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# ...

# %% [markdown]
# Observation: Each record has a single offense from an incident.

# %%
#grouping the incident number and aggregate the data using count method.
crime.groupby('INCIDENT_NUMBER').count()
# Out:
#                  OFFENSE_CODE  OFFENSE_CODE_GROUP  OFFENSE_DESCRIPTION  \
# INCIDENT_NUMBER
# I010370257-00               1                   1                    1
# I020662996-00               1                   1                    1
# I020669075-00               1                   1                    1
# I020674147-00               1                   1                    1
# I020691165-00               1                   1                    1
# ...                       ...                 ...                  ...
# I192064800                  1                   1                    1
# I192064803                  1                   1                    1
# I192064808                  1                   1                    1
# I192064810                  1                   1                    1
# I192064813                  1                   1                    1
#
#                  DISTRICT  REPORTING_AREA  SHOOTING  OCCURRED_ON_DATE  YEAR  \
# INCIDENT_NUMBER
# ...

# %% [markdown]
# Observation: Each row has the distinct incident number with all offenses tagged to the incident.

# %%
offense=pd.read_excel(r'C:\Users\admin\Desktop\offense_codes_boston.xlsx')
offense
# Out:
#      CODE                                       NAME
# 0     612           LARCENY PURSE SNATCH - NO FORCE
# 1     613                        LARCENY SHOPLIFTING
# 2     615    LARCENY THEFT OF MV PARTS & ACCESSORIES
# 3    1731                                     INCEST
# 4    3111                  LICENSE PREMISE VIOLATION
# ..    ...                                        ...
# 571  1806  DRUGS - CLASS B TRAFFICKING OVER 18 GRAMS
# 572  1807  DRUGS - CLASS D TRAFFICKING OVER 50 GRAMS
# 573  1610    HUMAN TRAFFICKING - COMMERCIAL SEX ACTS
# 574  2010                              HOME INVASION
# 575  1620  HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE
#
# [576 rows x 2 columns]

# %% [markdown]
# Observation: Each record represents a single incident.

# %% [markdown]
# Granulairty Observation:
#     > Dataset offense has coarser granulairty than crimes dataset because within an incident there can be multiple offenses.

# %% [markdown]
# # Identify Scope

# %%
crime
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0           I192064813          3006               Medical Assistance
# 1           I192064810          3410                            Towed
# 2           I192064808          2003  Offenses Against Child / Family
# 3           I192064803           802                   Simple Assault
# 4           I192064800          3114             Investigate Property
# ...                ...           ...                              ...
# 413667   I020691165-00          3125                  Warrant Arrests
# 413668   I020674147-00          3125                  Warrant Arrests
# 413669   I020669075-00          3125                  Warrant Arrests
# 413670   I020662996-00          3125                  Warrant Arrests
# 413671   I010370257-00          3125                  Warrant Arrests
#
#                     OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# ...

# %% [markdown]
# Observations: This report contains the crime incidents in Boston spanning from 15-june-15 2015 to 17-aug-2019. This has limited scope related to geographic location and time coverage.

# %% [markdown]
# # Temporality

# %%
crime['OCCURRED_ON_DATE']
# Out:
# 0         2019-08-17 21:00:00
# 1         2019-08-17 21:15:00
# 2         2019-08-17 19:33:00
# 3         2019-08-17 20:55:00
# 4         2019-08-17 19:39:00
#                  ...
# 413667    2019-05-23 08:00:00
# 413668    2019-05-23 08:00:00
# 413669    2019-05-23 08:00:00
# 413670    2019-05-23 08:56:00
# 413671    2016-05-31 19:35:00
# Name: OCCURRED_ON_DATE, Length: 413672, dtype: object

# %% [markdown]
# Observations: OCCURED_ON_DATE series does not contain suspicious values and have the format in the timestamp (year-mm-dd)

# %% [markdown]
# # Faithfulness

# %%
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I192064813          3006               Medical Assistance
# 1      I192064810          3410                            Towed
# 2      I192064808          2003  Offenses Against Child / Family
# 3      I192064803           802                   Simple Assault
# 4      I192064800          3114             Investigate Property
#
#                OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0    SICK/INJURED/MEDICAL - PERSON      D14            794      NaN
# 1              TOWED MOTOR VEHICLE       B3            435      NaN
# 2  CHILD ENDANGERMENT (NO ASSAULT)      C11            355      NaN
# 3         ASSAULT SIMPLE - BATTERY      E18            554      NaN
# 4             INVESTIGATE PROPERTY      E18            502      NaN
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0  2019-08-17 21:00:00  2019      8    Saturday    21  Part Three
# ...

# %% [markdown]
# Observations: Is considered as failthful, if you think it accuately captures reality. It may contain unreleastic values for e.g. dates in the future that represents events in the past, non existant locations, negative values that represent amounts and extreme outliers. Unfailthful data contain inconsistencies for e.g. age column and birthday column not matching up, handentered can contain spelling mistakes.
